# %% [markdown]
# # Candle Notebook: Common Setup
#
# This notebook uses the shared image-store and HTML helpers from `candle_notebooks`. The first cells configure dependencies, working directory, and the image store.

# %%
// Environment Setup
// Configure dependencies and workspace

// Core dependencies
:dep candle-core = { path = "../../../../candle-core" }
:dep candle-nn = { path = "../../../../candle-nn" }
:dep candle-notebooks = { path = "." }

// Import required modules
use candle_core::{Device, Tensor};
use candle_notebooks as nb;

println!("✓ Dependencies loaded: candle-core, candle-nn, candle-notebooks");

# %%
// Standard notebook initialization with working directory and image store management
nb::set_notebook_cwd().unwrap();
nb::set_image_store_rel_dir("images_store").unwrap();
std::fs::create_dir_all("images_store").ok();

println!("✓ Notebook initialized successfully!");
println!("  Working directory: {:?}", std::env::current_dir().unwrap());
println!("  Image store: images_store/");
println!("  Location: research/notebooks/candle_notebooks/temp_run_cells.ipynb");
